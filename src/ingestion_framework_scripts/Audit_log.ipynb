# %%
# %sql
SELECT source_id, rows_read, rows_written, status, ingestion_timestamp
FROM nestle_dev_silver.control.ingestion_audit_log
WHERE source_id = 'sharepoint_regional_targets'
ORDER BY ingestion_timestamp DESC
LIMIT 3;
